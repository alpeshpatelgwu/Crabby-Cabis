# %%
import pandas as pd

# %%
excel = "/Users/patrickwolfe/Desktop/2013-2017 ACS 5-Year Ward.xls"

# %%
tables = pd.read_excel(excel)
tables
# Out:
#                                             Unnamed: 0 Ward 1 Estimate  \
# 0                                    HOUSING OCCUPANCY             NaN
# 1                                  Total housing units           38340
# 2                               Occupied housing units           35314
# 3                                 Vacant housing units            3026
# 4                                                  NaN             NaN
# 5                               Homeowner vacancy rate             1.9
# 6                                  Rental vacancy rate             4.6
# 7                                                  NaN             NaN
# 8                                   UNITS IN STRUCTURE             NaN
# 9                                  Total housing units           38340
# 10                                    1-unit, detached             803
# 11                                    1-unit, attached            7906
# ...

# %%
tables.iloc[1]
# Out:
# DP04: SELECTED HOUSING CHARACTERISTICS IN THE DISTRICT OF COLUMBIA    Subject
# Unnamed: 1                                                            Ward 1
# Unnamed: 2                                                                NaN
# Unnamed: 3                                                             Ward 2
# Unnamed: 4                                                                NaN
# Unnamed: 5                                                            Ward 3
# Unnamed: 6                                                                NaN
# Unnamed: 7                                                            Ward 4
# Unnamed: 8                                                                NaN
# Unnamed: 9                                                            Ward 5
# Unnamed: 10                                                               NaN
# Unnamed: 11                                                            Ward 6
# ...

# %%
tables.rename(columns = tables.iloc[1])
# Out:
#                                                Subject   Ward 1       NaN  \
# 0    2013-2017 American Community Survey 5-Year Est...       NaN      NaN
# 1                                              Subject   Ward 1       NaN
# 2                                                  NaN  Estimate  Percent
# 3                                    HOUSING OCCUPANCY       NaN      NaN
# 4                                  Total housing units     38340    38340
# 5                               Occupied housing units     35314    0.921
# 6                                 Vacant housing units      3026    0.079
# 7                                                  NaN       NaN      NaN
# 8                               Homeowner vacancy rate       1.9      (X)
# 9                                  Rental vacancy rate       4.6      (X)
# 10                                                 NaN       NaN      NaN
# 11                                  UNITS IN STRUCTURE       NaN      NaN
# ...

# %%
tables.dropna()
# Out:
#     DP04: SELECTED HOUSING CHARACTERISTICS IN THE DISTRICT OF COLUMBIA  \
# 4                                  Total housing units
# 5                               Occupied housing units
# 6                                 Vacant housing units
# 8                               Homeowner vacancy rate
# 9                                  Rental vacancy rate
# 12                                 Total housing units
# 13                                    1-unit, detached
# 14                                    1-unit, attached
# 15                                             2 units
# 16                                        3 or 4 units
# 17                                        5 to 9 units
# 18                                      10 to 19 units
# 19                                    20 or more units
# 20                                         Mobile home
# 21                                 Boat, RV, van, etc.
# 24                                 Total housing units
# ...

# %%
cols = ["DP04: SELECTED HOUSING CHARACTERISTICS IN THE DISTRICT OF COLUMBIA", "Ward 1 Estimate", "Ward 1 Percent", "Ward 2 Estimate", "Ward 2 Percent", "Ward 3 Estimate", "Ward 3 Percent", "Ward 4 Estimate", "Ward 4 Percent", "Ward 5 Estimate", "Ward 5 Percent", "Ward 6 Estimate", "Ward 6 Percent," "Ward 7 Estimate", "Ward 7 Percent", "Ward 8 Estimate", "Ward 8 Percent"]

tables.rename(columns = cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-439436c1b815> in <module>
#       1 cols = ["DP04: SELECTED HOUSING CHARACTERISTICS IN THE DISTRICT OF COLUMBIA", "Ward 1 Estimate", "Ward 1 Percent", "Ward 2 Estimate", "Ward 2 Percent", "Ward 3 Estimate", "Ward 3 Percent", "Ward 4 Estimate", "Ward 4 Percent", "Ward 5 Estimate", "Ward 5 Percent", "Ward 6 Estimate", "Ward 6 Percent," "Ward 7 Estimate", "Ward 7 Percent", "Ward 8 Estimate", "Ward 8 Percent"]
#       2
# ----> 3 tables.rename(columns = cols)
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ...
