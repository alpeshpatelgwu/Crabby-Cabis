# %%
import pandas as pd

# %%
excel = "./2013-2017 ACS 5-Year Ward cleaned.xlsx"

# %%
tables = pd.read_excel(excel)
tables
# Out:
#                             Category                       Measure  WARD  \
# 0                  HOUSING OCCUPANCY           Total housing units     1
# 1                  HOUSING OCCUPANCY           Total housing units     1
# 2                  HOUSING OCCUPANCY           Total housing units     2
# 3                  HOUSING OCCUPANCY           Total housing units     2
# 4                  HOUSING OCCUPANCY           Total housing units     3
# 5                  HOUSING OCCUPANCY           Total housing units     3
# 6                  HOUSING OCCUPANCY           Total housing units     4
# 7                  HOUSING OCCUPANCY           Total housing units     4
# 8                  HOUSING OCCUPANCY           Total housing units     5
# 9                  HOUSING OCCUPANCY           Total housing units     5
# 10                 HOUSING OCCUPANCY           Total housing units     6
# 11                 HOUSING OCCUPANCY           Total housing units     6
# ...

# %%
tables.iloc[2]
# Out:
# Category          HOUSING OCCUPANCY
# Measure         Total housing units
# WARD                              2
# Type                       Estimate
# Value                         43373
# Name: 2, dtype: object
