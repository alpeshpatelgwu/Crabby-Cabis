# %%
#pip install shapely

# %%
#Import dependencies
import pandas as pd
import numpy as np
import json
from shapely.geometry import shape, Point
import path
import glob
from numpy import radians, cos, sin, arcsin, sqrt
import datetime 
import matplotlib.pyplot as plt

# %%
#Import CSV

locations_df = pd.read_csv('./Capital_Bike_Share_Locations.csv')
locations_df["NUMBER_OF_BIKES"] = locations_df["NUMBER_OF_BIKES"] + locations_df["NUMBER_OF_EMPTY_DOCKS"]
locations_df.drop(columns=["NUMBER_OF_EMPTY_DOCKS", "INSTALLED", "LOCKED", "INSTALL_DATE", "REMOVAL_DATE", "TEMPORARY_INSTALL", "SE_ANNO_CAD_DATA", "X", "Y"], inplace=True)
locations_df.rename(columns={'NUMBER_OF_BIKES': 'TOTAL_BIKE_DOCKS'}, inplace=True)
locations_df["WARD"] = ""
locations_df.head()
# Out:
#     OBJECTID  ID                     ADDRESS  TERMINAL_NUMBER   LATITUDE  \
# 0  237709931  90  34th St & Wisconsin Ave NW            31226  38.916442
# 1  237709932  91   13th St & New York Ave NW            31227  38.900283
# 2  237709933  92               8th & H St NW            31228  38.899700
# 3  237709934  93         10th & Monroe St NE            31504  38.932514
# 4  237709935  94      Eckington Pl & Q St NE            31505  38.910972
#
#    LONGITUDE  TOTAL_BIKE_DOCKS OWNER WARD
# 0 -77.068200                 8    DC
# 1 -77.029822                21    DC
# 2 -77.023086                30    DC
# 3 -76.992889                11    DC
# 4 -77.004950                22    DC

# %%
# load GeoJSON file containing sectors
with open('./dc-ward-map-overlay.geojson') as f:
    js = json.load(f)

# construct point based on lon/lat returned by geocoder
# check each polygon to see if it contains the point
for index, row in locations_df.iterrows():
    point = Point(row['LONGITUDE'],row['LATITUDE'])
    for feature in js['features']:
        polygon = shape(feature['geometry'])
        if polygon.contains(point):
            locations_df.loc[index,'WARD'] = feature["properties"]["name"]

locations_df["WARD"] = locations_df["WARD"].str.replace("Ward ", "")

# %%
locations_df.head()
# Out:
#     OBJECTID  ID                     ADDRESS  TERMINAL_NUMBER   LATITUDE  \
# 0  237709931  90  34th St & Wisconsin Ave NW            31226  38.916442
# 1  237709932  91   13th St & New York Ave NW            31227  38.900283
# 2  237709933  92               8th & H St NW            31228  38.899700
# 3  237709934  93         10th & Monroe St NE            31504  38.932514
# 4  237709935  94      Eckington Pl & Q St NE            31505  38.910972
#
#    LONGITUDE  TOTAL_BIKE_DOCKS OWNER WARD
# 0 -77.068200                 8    DC    2
# 1 -77.029822                21    DC    2
# 2 -77.023086                30    DC    2
# 3 -76.992889                11    DC    5
# 4 -77.004950                22    DC    5

# %%
#Loop thru all CSV files, and add to DataFrame
list_ = []
path = '../capbikeshare stuff/CSV Files'
allFiles = glob.glob(path + "/*.csv")
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)

# %%
merged_df = pd.merge(frame, locations_df, left_on='Start station number', right_on='TERMINAL_NUMBER')
merged_df.rename(columns={'WARD': 'Start Ward'}, inplace=True)
merged_df.drop(columns=["OBJECTID", "ID", "ADDRESS", "TERMINAL_NUMBER", "LATITUDE", "LONGITUDE", "TOTAL_BIKE_DOCKS", "OWNER"], inplace=True)

# %%
bs_ward = pd.merge(merged_df, locations_df, left_on='End station number', right_on='TERMINAL_NUMBER')
bs_ward.rename(columns={'WARD': 'End Ward'}, inplace=True)
bs_ward = bs_ward[bs_ward["OWNER"] == "DC"]
bs_ward.drop(columns=["OBJECTID", "ID", "ADDRESS", "TERMINAL_NUMBER", "LATITUDE", "LONGITUDE", "TOTAL_BIKE_DOCKS", "OWNER"], inplace=True)

# %%
bs_ward.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       679  2018-05-01 00:00:00  2018-05-01 00:11:19                 31302
# 1       320  2018-05-01 06:55:30  2018-05-01 07:00:51                 31302
# 2       314  2018-05-01 10:37:14  2018-05-01 10:42:29                 31302
# 3       687  2018-05-01 20:48:32  2018-05-01 21:00:00                 31302
# 4       557  2018-05-02 13:05:04  2018-05-02 13:14:22                 31302
#
#                   Start station  End station number  \
# 0  Wisconsin Ave & Newark St NW               31307
# 1  Wisconsin Ave & Newark St NW               31307
# 2  Wisconsin Ave & Newark St NW               31307
# 3  Wisconsin Ave & Newark St NW               31307
# 4  Wisconsin Ave & Newark St NW               31307
#
#                               End station Bike number Member type Start Ward  \
# 0  3000 Connecticut Ave NW / National Zoo      W22771      Member          3
# 1  3000 Connecticut Ave NW / National Zoo      W21410      Member          3
# 2  3000 Connecticut Ave NW / National Zoo      W20032      Member          3
# 3  3000 Connecticut Ave NW / National Zoo      W21882      Member          3
# 4  3000 Connecticut Ave NW / National Zoo      W20409      Member          3
#
#   End Ward
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3

# %%
bs_ward_count_gb = bs_ward.groupby("Start Ward")
bs_ward_count = bs_ward_count_gb["Start station number"].count()
bs_ward_count = pd.DataFrame(bs_ward_count).reset_index()
bs_ward_count = bs_ward_count.drop(bs_ward_count.index[0]).reset_index(drop=True)
bs_ward_count.rename(columns={'Start station number': 'Total Rides'}, inplace=True)
bs_ward_count
# Out:
#   Start Ward  Total Rides
# 0          1       382944
# 1          2      1647351
# 2          3        83923
# 3          4        39175
# 4          5       129719
# 5          6       750547
# 6          7         9066
# 7          8        10758

# %%
bs_ward_count_gb = bs_ward.groupby("Start Ward")
bs_ward_count_duration = bs_ward_count_gb["Duration"].sum()
bs_ward_count_duration = pd.DataFrame(bs_ward_count_duration).reset_index()
bs_ward_count_duration = bs_ward_count_duration.drop(bs_ward_count_duration.index[0]).reset_index(drop=True)
bs_ward_count_duration.rename(columns={'Duration': 'Total Duration'}, inplace=True)

bs_ward_count_duration
# Out:
#   Start Ward  Total Duration
# 0          1       306709128
# 1          2      2173091538
# 2          3        85693441
# 3          4        44637299
# 4          5       130542738
# 5          6       703145440
# 6          7        14553811
# 7          8        15683870

# %%
excel = "./2013-2017 ACS 5-Year Ward cleaned.xlsx"

ward_stats = pd.read_excel(excel)
#ward_stats.drop(columns=["Category"], inplace=True)
ward_stats["Category_Measure"] = ""

for index, row in ward_stats.iterrows():
    ward_stats.loc[index,'Category'] = ward_stats.loc[index,'Category'].strip().title()
    ward_stats.loc[index,'Measure'] = ward_stats.loc[index,'Measure'].strip()

ward_stats["Category_Measure"] = ward_stats['Category'] + " - " + ward_stats['Measure']


ward_stats.head()
# Out:
#             Category              Measure  WARD      Type    Value  \
# 0  Housing Occupancy  Total housing units     1  Estimate  38340.0
# 1  Housing Occupancy  Total housing units     1   Percent  38340.0
# 2  Housing Occupancy  Total housing units     2  Estimate  43373.0
# 3  Housing Occupancy  Total housing units     2   Percent  43373.0
# 4  Housing Occupancy  Total housing units     3  Estimate  41049.0
#
#                           Category_Measure
# 0  Housing Occupancy - Total housing units
# 1  Housing Occupancy - Total housing units
# 2  Housing Occupancy - Total housing units
# 3  Housing Occupancy - Total housing units
# 4  Housing Occupancy - Total housing units

# %%
ward_stats_estimate = ward_stats.copy()
ward_stats_estimate = ward_stats_estimate[(ward_stats_estimate["Type"] == "Estimate")].reset_index(drop = True)
ward_stats_estimate.drop(columns=["Type"], inplace=True)
#ward_stats_estimate.pivot(index='WARD', columns='Measure', values='Value')
ward_stats_estimate = pd.pivot_table(ward_stats_estimate, values='Value', index=["WARD"], columns=['Category_Measure'], aggfunc=np.mean).reset_index(drop = True)
ward_stats_estimate["Bike Rides by Ward"] = bs_ward_count["Total Rides"]
ward_stats_estimate.dropna(axis='columns', inplace = True)
ward_stats_estimate
# Out:
# Category_Measure  Ancestry - American  Ancestry - Arab  Ancestry - Czech  \
# 0                              1312.0            635.0             287.0
# 1                              1593.0           1369.0             473.0
# 2                              2795.0           1074.0             384.0
# 3                              2082.0            405.0             148.0
# 4                              2242.0            196.0             161.0
# 5                              1885.0            512.0             445.0
# 6                              1730.0             74.0              22.0
# 7                              1701.0            111.0              15.0
#
# Category_Measure  Ancestry - Danish  Ancestry - Dutch  Ancestry - English  \
# 0                             347.0             625.0              5204.0
# 1                             330.0             613.0              6239.0
# 2                             379.0            1281.0              9302.0
# 3                             116.0             286.0              2439.0
# 4                             139.0             347.0              2017.0
# 5                             415.0            1105.0              7143.0
# 6                               0.0              23.0               351.0
# 7                              58.0              85.0               676.0
#
# Category_Measure  Ancestry - French (except Basque)  \
# 0                                            1234.0
# 1                                            2340.0
# 2                                            2442.0
# 3                                             990.0
# 4                                             731.0
# 5                                            2072.0
# 6                                              28.0
# 7                                             265.0
#
# Category_Measure  Ancestry - French Canadian  Ancestry - German  \
# 0                                      388.0             8169.0
# 1                                      381.0             8674.0
# 2                                      682.0            10334.0
# 3                                      118.0             3951.0
# 4                                      155.0             3845.0
# 5                                      531.0            10546.0
# 6                                       44.0              350.0
# 7                                       90.0             1003.0
#
# Category_Measure  Ancestry - Greek  ...  \
# 0                            455.0  ...
# 1                            512.0  ...
# 2                            794.0  ...
# 3                            205.0  ...
# 4                            183.0  ...
# 5                            369.0  ...
# 6                             10.0  ...
# 7                              7.0  ...
#
# Category_Measure  Year Structure Built - Built 2010 to 2013  \
# 0                                                     991.0
# 1                                                     849.0
# 2                                                     242.0
# 3                                                     325.0
# 4                                                    2330.0
# 5                                                    2728.0
# 6                                                     709.0
# 7                                                    1199.0
#
# Category_Measure  Year Structure Built - Built 2014 or later  \
# 0                                                      364.0
# 1                                                      479.0
# 2                                                      272.0
# 3                                                      298.0
# 4                                                      525.0
# 5                                                     1953.0
# 6                                                      139.0
# 7                                                      250.0
#
# Category_Measure  Years Responsible For Grandchildren - 1 or 2 years  \
# 0                                                             105.0
# 1                                                               0.0
# 2                                                              18.0
# 3                                                             155.0
# 4                                                             106.0
# 5                                                             113.0
# 6                                                             404.0
# 7                                                             299.0
#
# Category_Measure  Years Responsible For Grandchildren - 3 or 4 years  \
# 0                                                               0.0
# 1                                                               0.0
# 2                                                               0.0
# 3                                                              34.0
# 4                                                              96.0
# 5                                                              13.0
# 6                                                             216.0
# 7                                                             192.0
#
# Category_Measure  Years Responsible For Grandchildren - 5 or more years  \
# 0                                                              48.0
# 1                                                               0.0
# 2                                                              13.0
# 3                                                             265.0
# 4                                                             212.0
# 5                                                              57.0
# 6                                                             501.0
# 7                                                             608.0
#
# Category_Measure  Years Responsible For Grandchildren - Less than 1 year  \
# 0                                                              19.0
# 1                                                              10.0
# 2                                                               0.0
# 3                                                             131.0
# 4                                                              92.0
# 5                                                               5.0
# 6                                                             148.0
# 7                                                             205.0
#
# Category_Measure  Years Responsible For Grandchildren - Number of grandparents responsible for own grandchildren under 18 years  \
# 0                                                             172.0
# 1                                                              10.0
# 2                                                              31.0
# 3                                                             585.0
# 4                                                             506.0
# 5                                                             188.0
# 6                                                            1269.0
# 7                                                            1304.0
#
# Category_Measure  Years Responsible For Grandchildren - Who are female  \
# 0                                                             172.0
# 1                                                               0.0
# 2                                                              22.0
# 3                                                             344.0
# 4                                                             370.0
# 5                                                             131.0
# 6                                                             955.0
# 7                                                            1033.0
#
# Category_Measure  Years Responsible For Grandchildren - Who are married  \
# 0                                                              64.0
# 1                                                              10.0
# 2                                                              31.0
# 3                                                             361.0
# 4                                                             274.0
# 5                                                              40.0
# 6                                                             617.0
# 7                                                             459.0
#
# Category_Measure  Bike Rides by Ward
# 0                             382944
# 1                            1647351
# 2                              83923
# 3                              39175
# 4                             129719
# 5                             750547
# 6                               9066
# 7                              10758
#
# [8 rows x 419 columns]

# %%
ward_stats_percent = ward_stats.copy()
ward_stats_percent = ward_stats_percent[(ward_stats_percent["Type"] == "Percent")].reset_index(drop = True)
ward_stats_percent.drop(columns=["Type"], inplace=True)
#ward_stats_estimate.pivot(index='WARD', columns='Measure', values='Value')
ward_stats_percent = pd.pivot_table(ward_stats_percent, values='Value', index=["WARD"], columns=['Category_Measure'], aggfunc=np.mean).reset_index(drop = True)
ward_stats_percent["Bike Rides by Ward"] = bs_ward_count["Total Rides"]
ward_stats_percent.dropna(axis='columns', inplace = True)
ward_stats_percent
# Out:
# Category_Measure  Ancestry - American  Ancestry - Arab  Ancestry - Czech  \
# 0                               0.016            0.008             0.003
# 1                               0.020            0.018             0.006
# 2                               0.033            0.013             0.005
# 3                               0.025            0.005             0.002
# 4                               0.026            0.002             0.002
# 5                               0.021            0.006             0.005
# 6                               0.022            0.001             0.000
# 7                               0.020            0.001             0.000
#
# Category_Measure  Ancestry - Danish  Ancestry - Dutch  Ancestry - English  \
# 0                             0.004             0.007               0.062
# 1                             0.004             0.008               0.080
# 2                             0.005             0.015               0.111
# 3                             0.001             0.003               0.029
# 4                             0.002             0.004               0.023
# 5                             0.005             0.012               0.078
# 6                             0.000             0.000               0.004
# 7                             0.001             0.001               0.008
#
# Category_Measure  Ancestry - French (except Basque)  \
# 0                                             0.015
# 1                                             0.030
# 2                                             0.029
# 3                                             0.012
# 4                                             0.008
# 5                                             0.023
# 6                                             0.000
# 7                                             0.003
#
# Category_Measure  Ancestry - French Canadian  Ancestry - German  \
# 0                                      0.005              0.098
# 1                                      0.005              0.111
# 2                                      0.008              0.123
# 3                                      0.001              0.047
# 4                                      0.002              0.045
# 5                                      0.006              0.116
# 6                                      0.001              0.004
# 7                                      0.001              0.012
#
# Category_Measure  Ancestry - Greek  ...  \
# 0                            0.005  ...
# 1                            0.007  ...
# 2                            0.009  ...
# 3                            0.002  ...
# 4                            0.002  ...
# 5                            0.004  ...
# 6                            0.000  ...
# 7                            0.000  ...
#
# Category_Measure  Year Structure Built - Built 2010 to 2013  \
# 0                                                     0.026
# 1                                                     0.020
# 2                                                     0.006
# 3                                                     0.010
# 4                                                     0.063
# 5                                                     0.059
# 6                                                     0.021
# 7                                                     0.035
#
# Category_Measure  Year Structure Built - Built 2014 or later  \
# 0                                                      0.009
# 1                                                      0.011
# 2                                                      0.007
# 3                                                      0.009
# 4                                                      0.014
# 5                                                      0.042
# 6                                                      0.004
# 7                                                      0.007
#
# Category_Measure  Years Responsible For Grandchildren - 1 or 2 years  \
# 0                                                             0.105
# 1                                                             0.000
# 2                                                             0.093
# 3                                                             0.083
# 4                                                             0.062
# 5                                                             0.133
# 6                                                             0.151
# 7                                                             0.109
#
# Category_Measure  Years Responsible For Grandchildren - 3 or 4 years  \
# 0                                                             0.000
# 1                                                             0.000
# 2                                                             0.000
# 3                                                             0.018
# 4                                                             0.056
# 5                                                             0.015
# 6                                                             0.081
# 7                                                             0.070
#
# Category_Measure  Years Responsible For Grandchildren - 5 or more years  \
# 0                                                             0.048
# 1                                                             0.000
# 2                                                             0.067
# 3                                                             0.142
# 4                                                             0.125
# 5                                                             0.067
# 6                                                             0.188
# 7                                                             0.221
#
# Category_Measure  Years Responsible For Grandchildren - Less than 1 year  \
# 0                                                             0.019
# 1                                                             0.250
# 2                                                             0.000
# 3                                                             0.070
# 4                                                             0.054
# 5                                                             0.006
# 6                                                             0.055
# 7                                                             0.074
#
# Category_Measure  Years Responsible For Grandchildren - Number of grandparents responsible for own grandchildren under 18 years  \
# 0                                                             172.0
# 1                                                              10.0
# 2                                                              31.0
# 3                                                             585.0
# 4                                                             506.0
# 5                                                             188.0
# 6                                                            1269.0
# 7                                                            1304.0
#
# Category_Measure  Years Responsible For Grandchildren - Who are female  \
# 0                                                             1.000
# 1                                                             0.000
# 2                                                             0.710
# 3                                                             0.588
# 4                                                             0.731
# 5                                                             0.697
# 6                                                             0.753
# 7                                                             0.792
#
# Category_Measure  Years Responsible For Grandchildren - Who are married  \
# 0                                                             0.372
# 1                                                             1.000
# 2                                                             1.000
# 3                                                             0.617
# 4                                                             0.542
# 5                                                             0.213
# 6                                                             0.486
# 7                                                             0.352
#
# Category_Measure  Bike Rides by Ward
# 0                             382944
# 1                            1647351
# 2                              83923
# 3                              39175
# 4                             129719
# 5                             750547
# 6                               9066
# 7                              10758
#
# [8 rows x 401 columns]

# %%
# ward_stats_cats = ward_stats.copy()
# ward_stats_cats.drop_duplicates("Category", inplace = True)

# ward_stats_cats.drop(columns=["Measure", "WARD", "Type", "Value", "Category_Measure"], inplace=True)
# ward_stats_cats.reindex()
# ward_stats_cats.head()

# %%
#RANDOM FOREST
# Create a random forest classifier
from sklearn.ensemble import RandomForestClassifier

features = ward_stats_estimate
target = np.array(features['Bike Rides by Ward'])
feature_names = list(features.columns)
features = features.drop('Bike Rides by Ward', axis = 1)
features = np.array(features)
target_name = feature_names.pop()

# %%
from sklearn.datasets import load_iris
 # Load the Iris Dataset
iris = load_iris()
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
from sklearn import tree
import graphviz 
import pydotplus

clf = tree.DecisionTreeClassifier()
clf = clf.fit(features, target)

dot_data = tree.export_graphviz(
    clf, out_file=None, 
    feature_names=feature_names,  
    class_names=target_name,  
    filled=True, rounded=True,  
    special_characters=True)  

graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_png('iristree.png')

graph = graphviz.Source(dot_data)  
graph

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(features, target)
rf.score(features, target)
# Out:
# 1.0

# %%
import pandas as pd
important_features = pd.Series(data=clf.feature_importances_,index=feature_names)
important_features.sort_values(ascending=False,inplace=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
results_estimated = []

for column in ward_stats_estimate:
    #print(ward_stats_estimate[column])
    X = ward_stats_estimate["Bike Rides by Ward"].values.reshape(-1, 1)
    y = ward_stats_estimate[column].values.reshape(-1, 1)
    model = LinearRegression()
    model.fit(X, y)
    model_coef = model.coef_
    model_intercept = model.intercept_
    model_score = model.score(X, y)
#     print(ward_stats_estimate[column].name)
#     print('Weight coefficients: ', model_coef)
#     print('y-axis intercept: ', model_intercept) 
#     print('Score: ', model_score)     
    results_estimated.append({"Model - Estimated": ward_stats_estimate[column].name, 'Weight coefficients': model_coef, 'y-axis intercept': model_intercept, 'Score': model_score})

results_estimated = pd.DataFrame(results)

# %%
results_estimated.sort_values(by=["Score"], ascending=False)
# Out:
#                                      Model - Estimated     Score  \
# 418                                 Bike Rides by Ward  1.000000
# 286                  Residence 1 Year Ago - Same state  1.000000
# 45                          Commuting To Work - Walked  0.985378
# 250                                      Race - Korean  0.928100
# 288                                    Rooms - 2 rooms  0.841232
# 287                                     Rooms - 1 room  0.780008
# 42   Commuting To Work - Mean travel time to work (...  0.771067
# 155  Housing Tenure - Average household size of own...  0.766541
# 87                         Gross Rent - $3,000 or more  0.763860
# 63   Employment Status - All parents in family in l...  0.733482
# 32                               Bedrooms - No bedroom  0.727800
# 144  Households By Type - Households with one or mo...  0.726193
# 142      Households By Type - Householder living alone  0.722453
# 169  Income And Benefits (In 2017 Inflation-Adjuste...  0.709071
# 140  Households By Type - Family households (families)  0.709071
# 86                       Gross Rent - $2,500 to $2,999  0.707444
# 130                   House Heating Fuel - Electricity  0.704508
# 27                                Bedrooms - 1 bedroom  0.702775
# 289                                    Rooms - 3 rooms  0.700271
# 139        Households By Type - Average household size  0.699611
# 149  Households By Type - With own children of the ...  0.697019
# 185  Income And Benefits (In 2017 Inflation-Adjuste...  0.688537
# 147          Households By Type - Nonfamily households  0.688537
# 408          Year Structure Built - Built 2000 to 2009  0.687629
# 85                       Gross Rent - $2,000 to $2,499  0.681870
# 301      School Enrollment - Nursery school, preschool  0.669487
# 126  Hispanic Or Latino And Race - Two races includ...  0.665782
# 365           Units In Structure - Boat, RV, van, etc.  0.663761
# 138           Households By Type - Average family size  0.663253
# 297     School Enrollment - College or graduate school  0.662424
# ..                                                 ...       ...
# 133                    House Heating Fuel - Other fuel  0.008094
# 97   Gross Rent As A Percentage Of Household Income...  0.007717
# 218     Marital Status - Now married, except separated  0.006443
# 270  Race Alone Or In Combination With One Or More ...  0.006422
# 61   Educational Attainment - Population 25 years a...  0.006346
# 116  Hispanic Or Latino And Race - Hispanic or Lati...  0.005939
# 222  Mortgage Status - Housing units without a mort...  0.004788
# 318  Selected Monthly Owner Costs (Smoc) - Housing ...  0.004788
# 168  Income And Benefits (In 2017 Inflation-Adjuste...  0.004406
# 328  Selected Monthly Owner Costs As A Percentage O...  0.003706
# 230          Occupation - Sales and office occupations  0.003133
# 158                    Housing Tenure - Owner-occupied  0.003108
# 376                       Value - Owner-occupied units  0.003108
# 239           Race - American Indian and Alaska Native  0.002982
# 387  World Region Of Birth Of Foreign Born - Latin ...  0.002345
# 213  Language Spoken At Home - Speak English less t...  0.002200
# 34             Citizen, Voting Age Population - Female  0.001971
# 120  Hispanic Or Latino And Race - Other Hispanic o...  0.001782
# 266  Race Alone Or In Combination With One Or More ...  0.001470
# 211  Language Spoken At Home - Population 5 years a...  0.001251
# 322  Selected Monthly Owner Costs As A Percentage O...  0.001038
# 326  Selected Monthly Owner Costs As A Percentage O...  0.000618
# 302  School Enrollment - Population 3 years and ove...  0.000551
# 340                       Sex And Age - 35 to 44 years  0.000442
# 393  Year Householder Moved Into Unit - Moved in 20...  0.000331
# 212                  Language Spoken At Home - Spanish  0.000295
# 290                                    Rooms - 4 rooms  0.000289
# 193  Industry - Agriculture, forestry, fishing and ...  0.000066
# 371                       Value - $300,000 to $499,999  0.000038
# 107    Health Insurance Coverage - Not in labor force:  0.000013
#
#              Weight coefficients         y-axis intercept
# 418       [[0.9999999999999998]]  [5.820766091346741e-11]
# 286                     [[-0.0]]                    [0.0]
# 45      [[0.011702614599397941]]     [1404.1581581483224]
# 250    [[0.0005673204171004808]]     [132.71209385384657]
# 288    [[0.0037737369878398323]]     [1823.3697826449832]
# 287    [[0.0035589961517133273]]     [1340.2082192097419]
# 42    [[-6.403880655906708e-06]]     [33.156767589604996]
# 155   [[-5.806552007686194e-07]]      [2.644127598051071]
# 87      [[0.002004327270431038]]      [726.6025941628028]
# 63    [[-0.0029593460080046667]]      [6309.226590820014]
# 32      [[0.004216882834382475]]      [1683.477494027662]
# 144    [[-0.003925110445741285]]       [8972.40725239918]
# 142     [[0.005734223632823908]]     [12952.080702371744]
# 169    [[-0.004242910774783481]]     [16795.831990164774]
# 140    [[-0.004242910774783481]]     [16795.831990164774]
# 86     [[0.0017613729193965775]]      [700.7097167452725]
# 130      [[0.00703573960341902]]      [11465.56109106666]
# 27      [[0.005924012567303934]]      [9754.016041743886]
# 289     [[0.004319506298702174]]      [6525.557618564999]
# 139    [[-5.04643967102275e-07]]     [2.5001152218249194]
# 149   [[-0.0015606492887520196]]      [3798.677009020798]
# 185     [[0.009166906560478968]]     [16072.875831873625]
# 147     [[0.009166906560478968]]     [16072.875831873625]
# 408    [[0.0033263032650425457]]     [2081.8986909185114]
# 85     [[0.0023717469589759578]]     [1566.4888725581518]
# 301    [[-0.001132620004810677]]      [2283.554491268665]
# 126    [[0.0001608912647312214]]     [45.590157286839485]
# 365   [[1.4545754811110132e-05]]    [0.44809812026337514]
# 138   [[-5.558071221317969e-07]]      [3.414643449838546]
# 297     [[0.007550907274375732]]      [6440.054125389671]
# ..                           ...                      ...
# 133   [[2.0772997129375336e-05]]     [186.57125080080044]
# 97     [[0.0003106931897519688]]      [7249.787953359573]
# 218    [[0.0004757043467313329]]       [9954.74310802872]
# 270   [[-0.0004748293704472963]]     [4444.9854263201905]
# 61     [[0.0009789336262214696]]      [59356.73035177555]
# 116    [[0.0007317073785866564]]      [8699.342994813886]
# 222   [[-0.0001488005447908433]]     [3529.2949917386973]
# 318   [[-0.0001488005447908433]]     [3529.2949917386973]
# 168    [[-3.33775829847071e-05]]     [2577.5522352781118]
# 328  [[-0.00013077096711996115]]     [3456.9133656242952]
# 230    [[6.636529377699145e-05]]      [7433.544337957744]
# 158    [[0.0004356170392352369]]      [14308.10634702311]
# 376    [[0.0004356170392352369]]      [14308.10634702311]
# 239   [[1.2832874813305435e-05]]     [214.72687936455546]
# 387   [[0.00031991457616477087]]      [4951.018285028584]
# 213   [[-0.0001096227421612496]]      [1821.691397450345]
# 34    [[0.00022770070546893422]]      [33620.71497084532]
# 120   [[-0.0003583975947137138]]      [6425.545120337402]
# 266    [[1.665240549119907e-05]]      [781.6440203654396]
# 211   [[0.00021861305402272484]]      [78514.55859449544]
# 322  [[-1.4147000855111594e-05]]      [585.6497033265086]
# 326   [[-5.436300276727952e-06]]      [402.2624563097355]
# 302  [[-0.00012588412740623686]]       [20804.7981303756]
# 340    [[-7.04147974275901e-05]]     [11977.376298361698]
# 393  [[-2.3280136160796475e-05]]      [8745.510687500584]
# 212  [[-0.00013987400689832437]]      [7117.387862775739]
# 290   [[4.7646134554677836e-05]]      [7111.939167265197]
# 193   [[-2.591749490086302e-07]]     [40.973923287602965]
# 371  [[-1.5376266697146592e-05]]        [3887.2438961204]
# 107  [[-1.5632647534123224e-05]]     [11450.091752936305]
#
# [419 rows x 4 columns]

# %%
results_percent = []

for column in ward_stats_percent:
    X = ward_stats_percent["Bike Rides by Ward"].values.reshape(-1, 1)
    y = ward_stats_percent[column].values.reshape(-1, 1)
    model = LinearRegression()
    model.fit(X, y)
    model_coef = model.coef_
    model_intercept = model.intercept_
    model_score = model.score(X, y)
     
    results_percent.append({"Model - Percentage": ward_stats_percent[column].name, 'Weight coefficients': model_coef, 'y-axis intercept': model_intercept, 'Score': model_score})

results_percent = pd.DataFrame(results)

# %%
results_percent.sort_values(by=["Score"], ascending=False)
# Out:
#                                      Model - Estimated     Score  \
# 418                                 Bike Rides by Ward  1.000000
# 286                  Residence 1 Year Ago - Same state  1.000000
# 45                          Commuting To Work - Walked  0.985378
# 250                                      Race - Korean  0.928100
# 288                                    Rooms - 2 rooms  0.841232
# 287                                     Rooms - 1 room  0.780008
# 42   Commuting To Work - Mean travel time to work (...  0.771067
# 155  Housing Tenure - Average household size of own...  0.766541
# 87                         Gross Rent - $3,000 or more  0.763860
# 63   Employment Status - All parents in family in l...  0.733482
# 32                               Bedrooms - No bedroom  0.727800
# 144  Households By Type - Households with one or mo...  0.726193
# 142      Households By Type - Householder living alone  0.722453
# 169  Income And Benefits (In 2017 Inflation-Adjuste...  0.709071
# 140  Households By Type - Family households (families)  0.709071
# 86                       Gross Rent - $2,500 to $2,999  0.707444
# 130                   House Heating Fuel - Electricity  0.704508
# 27                                Bedrooms - 1 bedroom  0.702775
# 289                                    Rooms - 3 rooms  0.700271
# 139        Households By Type - Average household size  0.699611
# 149  Households By Type - With own children of the ...  0.697019
# 185  Income And Benefits (In 2017 Inflation-Adjuste...  0.688537
# 147          Households By Type - Nonfamily households  0.688537
# 408          Year Structure Built - Built 2000 to 2009  0.687629
# 85                       Gross Rent - $2,000 to $2,499  0.681870
# 301      School Enrollment - Nursery school, preschool  0.669487
# 126  Hispanic Or Latino And Race - Two races includ...  0.665782
# 365           Units In Structure - Boat, RV, van, etc.  0.663761
# 138           Households By Type - Average family size  0.663253
# 297     School Enrollment - College or graduate school  0.662424
# ..                                                 ...       ...
# 133                    House Heating Fuel - Other fuel  0.008094
# 97   Gross Rent As A Percentage Of Household Income...  0.007717
# 218     Marital Status - Now married, except separated  0.006443
# 270  Race Alone Or In Combination With One Or More ...  0.006422
# 61   Educational Attainment - Population 25 years a...  0.006346
# 116  Hispanic Or Latino And Race - Hispanic or Lati...  0.005939
# 222  Mortgage Status - Housing units without a mort...  0.004788
# 318  Selected Monthly Owner Costs (Smoc) - Housing ...  0.004788
# 168  Income And Benefits (In 2017 Inflation-Adjuste...  0.004406
# 328  Selected Monthly Owner Costs As A Percentage O...  0.003706
# 230          Occupation - Sales and office occupations  0.003133
# 158                    Housing Tenure - Owner-occupied  0.003108
# 376                       Value - Owner-occupied units  0.003108
# 239           Race - American Indian and Alaska Native  0.002982
# 387  World Region Of Birth Of Foreign Born - Latin ...  0.002345
# 213  Language Spoken At Home - Speak English less t...  0.002200
# 34             Citizen, Voting Age Population - Female  0.001971
# 120  Hispanic Or Latino And Race - Other Hispanic o...  0.001782
# 266  Race Alone Or In Combination With One Or More ...  0.001470
# 211  Language Spoken At Home - Population 5 years a...  0.001251
# 322  Selected Monthly Owner Costs As A Percentage O...  0.001038
# 326  Selected Monthly Owner Costs As A Percentage O...  0.000618
# 302  School Enrollment - Population 3 years and ove...  0.000551
# 340                       Sex And Age - 35 to 44 years  0.000442
# 393  Year Householder Moved Into Unit - Moved in 20...  0.000331
# 212                  Language Spoken At Home - Spanish  0.000295
# 290                                    Rooms - 4 rooms  0.000289
# 193  Industry - Agriculture, forestry, fishing and ...  0.000066
# 371                       Value - $300,000 to $499,999  0.000038
# 107    Health Insurance Coverage - Not in labor force:  0.000013
#
#              Weight coefficients         y-axis intercept
# 418       [[0.9999999999999998]]  [5.820766091346741e-11]
# 286                     [[-0.0]]                    [0.0]
# 45      [[0.011702614599397941]]     [1404.1581581483224]
# 250    [[0.0005673204171004808]]     [132.71209385384657]
# 288    [[0.0037737369878398323]]     [1823.3697826449832]
# 287    [[0.0035589961517133273]]     [1340.2082192097419]
# 42    [[-6.403880655906708e-06]]     [33.156767589604996]
# 155   [[-5.806552007686194e-07]]      [2.644127598051071]
# 87      [[0.002004327270431038]]      [726.6025941628028]
# 63    [[-0.0029593460080046667]]      [6309.226590820014]
# 32      [[0.004216882834382475]]      [1683.477494027662]
# 144    [[-0.003925110445741285]]       [8972.40725239918]
# 142     [[0.005734223632823908]]     [12952.080702371744]
# 169    [[-0.004242910774783481]]     [16795.831990164774]
# 140    [[-0.004242910774783481]]     [16795.831990164774]
# 86     [[0.0017613729193965775]]      [700.7097167452725]
# 130      [[0.00703573960341902]]      [11465.56109106666]
# 27      [[0.005924012567303934]]      [9754.016041743886]
# 289     [[0.004319506298702174]]      [6525.557618564999]
# 139    [[-5.04643967102275e-07]]     [2.5001152218249194]
# 149   [[-0.0015606492887520196]]      [3798.677009020798]
# 185     [[0.009166906560478968]]     [16072.875831873625]
# 147     [[0.009166906560478968]]     [16072.875831873625]
# 408    [[0.0033263032650425457]]     [2081.8986909185114]
# 85     [[0.0023717469589759578]]     [1566.4888725581518]
# 301    [[-0.001132620004810677]]      [2283.554491268665]
# 126    [[0.0001608912647312214]]     [45.590157286839485]
# 365   [[1.4545754811110132e-05]]    [0.44809812026337514]
# 138   [[-5.558071221317969e-07]]      [3.414643449838546]
# 297     [[0.007550907274375732]]      [6440.054125389671]
# ..                           ...                      ...
# 133   [[2.0772997129375336e-05]]     [186.57125080080044]
# 97     [[0.0003106931897519688]]      [7249.787953359573]
# 218    [[0.0004757043467313329]]       [9954.74310802872]
# 270   [[-0.0004748293704472963]]     [4444.9854263201905]
# 61     [[0.0009789336262214696]]      [59356.73035177555]
# 116    [[0.0007317073785866564]]      [8699.342994813886]
# 222   [[-0.0001488005447908433]]     [3529.2949917386973]
# 318   [[-0.0001488005447908433]]     [3529.2949917386973]
# 168    [[-3.33775829847071e-05]]     [2577.5522352781118]
# 328  [[-0.00013077096711996115]]     [3456.9133656242952]
# 230    [[6.636529377699145e-05]]      [7433.544337957744]
# 158    [[0.0004356170392352369]]      [14308.10634702311]
# 376    [[0.0004356170392352369]]      [14308.10634702311]
# 239   [[1.2832874813305435e-05]]     [214.72687936455546]
# 387   [[0.00031991457616477087]]      [4951.018285028584]
# 213   [[-0.0001096227421612496]]      [1821.691397450345]
# 34    [[0.00022770070546893422]]      [33620.71497084532]
# 120   [[-0.0003583975947137138]]      [6425.545120337402]
# 266    [[1.665240549119907e-05]]      [781.6440203654396]
# 211   [[0.00021861305402272484]]      [78514.55859449544]
# 322  [[-1.4147000855111594e-05]]      [585.6497033265086]
# 326   [[-5.436300276727952e-06]]      [402.2624563097355]
# 302  [[-0.00012588412740623686]]       [20804.7981303756]
# 340    [[-7.04147974275901e-05]]     [11977.376298361698]
# 393  [[-2.3280136160796475e-05]]      [8745.510687500584]
# 212  [[-0.00013987400689832437]]      [7117.387862775739]
# 290   [[4.7646134554677836e-05]]      [7111.939167265197]
# 193   [[-2.591749490086302e-07]]     [40.973923287602965]
# 371  [[-1.5376266697146592e-05]]        [3887.2438961204]
# 107  [[-1.5632647534123224e-05]]     [11450.091752936305]
#
# [419 rows x 4 columns]
