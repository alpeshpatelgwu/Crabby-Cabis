# %%
import pandas as pd
import numpy as np

# %%
excel = "./2013-2017 ACS 5-Year Ward cleaned.xlsx"

wards = pd.read_excel(excel)
wards.head()

#pd.pivot_table(wards, values='Value', index=["Category",'Measure', 'Type'], columns=['WARD'], aggfunc=np.mean)
# Out:
# WARD                                                                                                                     1  \
# Category                                           Measure                                            Type
#       Years responsible for grandchildren                  1 or 2 years                               Estimate    105.0000
#                                                                                                       Percent       0.1050
#                                                            3 or 4 years                               Estimate      0.0000
#                                                                                                       Percent       0.0000
#                                                            5 or more years                            Estimate     48.0000
#                                                                                                       Percent       0.0480
# ...
