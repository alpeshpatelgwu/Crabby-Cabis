# %%
import os
import csv
import numpy as np
import pandas as pd
from subprocess import check_output
#print(check_output(["ls", "/input"]).decode("utf8"))
print(os.listdir('input'))
# Out:
# ['724050-13743-2016.gz', '724050-13743-2017.gz', '724050-13743-2018.gz']

# %%
#noaa_weather_2016_df = pd.read_csv('input/724050-13743-2016.gz', compression='gzip',  header=0, sep=',', quotechar='"')

# %%
#noaa_weather_2016_df.head(100)

# %%
#noaa_weather_2017_df = pd.read_csv('input/724050-13743-2017.gz', compression='gzip',  header=0, sep=',', quotechar='"')

# %%
#noaa_weather_2017_df.head()

# %%
#noaa_weather_2018_df = pd.read_csv('input/724050-13743-2018.gz', compression='gzip',  header=0, sep=',', quotechar='"')

# %%
#noaa_weather_2018_df.head()

# %%
#noaa_weather_2018_df.to_csv(index=False)

# %%
# frames = [noaa_weather_2016_df, noaa_weather_2017_df, noaa_weather_2018_df]

# %%
# combined_df = pd.concat(frames)

# %%
# combined_df.head(200)

# %%
import requests

# %%
# url = "http://cabitracker.com/downloadoutage.php?s=2019-05-01&e=2019-05-10"
# r = requests.get(url)
# with open ('may2015.csv','wb') as f:
#     f.write(r.content)

# %%
# print(r.status_code)
# print(r.headers['content-type'])
# print(r.encoding)

# %%
import datetime
datetime_object = datetime.datetime.now()
print(datetime_object)
# Out:
# 2019-05-11 11:18:09.416250

# %%
today = datetime.date.today()


print(today)
# Out:
# 2019-05-11

# %%
#Looping through dates to download the right file
import datetime

#The size of each step in days
day_delta = datetime.timedelta(days=1)
start_date = datetime.date.today()
end_date = start_date - 15*day_delta
end_date_stop = "2016-10-01"

x = (start_date -end_date).days
y = (end_date - start_date).days

print(day_delta)
print(start_date)
print(end_date)
print(x)
print(y)
print(end_date_stop)
# Out:
# 1 day, 0:00:00
# 2019-05-11
# 2019-04-26
# 15
# -15
# 2016-10-01

# %%
tom_date = start_date + 15*day_delta
print(tom_date)
# Out:
# 2019-05-26

# %%
# Trying New Loop with proper for statement TOM
import datetime

day_delta = datetime.timedelta(days=1)
#start_date = datetime.date.today()
#end_date = start_date - 15*day_delta


def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

stop_date =  datetime.date.today()
start_date = datetime.date(2016,10,1)

for x in daterange(start_date, stop_date, 15):
    #y = x.strftime("%Y-%m-%d") + 15*(day_delta)
    y = x + 15*(day_delta)
    url = f"http://cabitracker.com/downloadoutage.php?s={x}&e={y}"
    r = requests.get(url)
    with open (f'{x}-{y}.csv','wb') as f:
        f.write(r.content)
        print(url)
    #x = y + 1*(day_delta)
    # print (x.strftime("%Y-%m-%d"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-b2d4bff10c9f> in <module>()
#      14 start_date = datetime.date(2016,10,1)
#      15
# ---> 16 for x in daterange(start_date, stop_date, 15):
#      17     #y = x.strftime("%Y-%m-%d") + 15*(day_delta)
#      18     y = x + 15*(day_delta)
#
# TypeError: daterange() takes 2 positional arguments but 3 were given

# %%
for i in range((start_date - end_date).days):
    print(end_date-i*day_delta)
# Out:
# 2019-04-26
# 2019-04-25
# 2019-04-24
# 2019-04-23
# 2019-04-22
# 2019-04-21
# 2019-04-20
# 2019-04-19
# 2019-04-18
# 2019-04-17
# 2019-04-16
# 2019-04-15
# 2019-04-14
# 2019-04-13
# 2019-04-12

# %%
#url = "http://cabitracker.com/downloadoutage.php?s=2019-05-01&e=2019-05-10"
url = f"http://cabitracker.com/downloadoutage.php?s={end_date}&e={start_date}"
r = requests.get(url)
with open (f'{end_date}-{start_date}.csv','wb') as f:
    f.write(r.content)
print(url)
# Out:
# http://cabitracker.com/downloadoutage.php?s=2019-04-25&e=2019-05-10

# %%
from datetime import timedelta, date
def daterange(start_date, end_date):
    for n in range(int ((start_date - end_date).days)):
        yield start_date + timedelta(n)

start_date = date(2019, 5, 10)
end_date = date(2016, 10, 1)
for single_date in daterange(start_date, end_date):
    print (single_date)
# Out:
# 2019-05-10
# 2019-05-11
# 2019-05-12
# 2019-05-13
# 2019-05-14
# 2019-05-15
# 2019-05-16
# 2019-05-17
# 2019-05-18
# 2019-05-19
# 2019-05-20
# 2019-05-21
# 2019-05-22
# 2019-05-23
# 2019-05-24
# 2019-05-25
# 2019-05-26
# 2019-05-27
# 2019-05-28
# 2019-05-29
# 2019-05-30
# 2019-05-31
# 2019-06-01
# 2019-06-02
# 2019-06-03
# 2019-06-04
# 2019-06-05
# 2019-06-06
# 2019-06-07
# 2019-06-08
# 2019-06-09
# 2019-06-10
# 2019-06-11
# 2019-06-12
# 2019-06-13
# 2019-06-14
# 2019-06-15
# 2019-06-16
# 2019-06-17
# 2019-06-18
# 2019-06-19
# 2019-06-20
# 2019-06-21
# 2019-06-22
# 2019-06-23
# 2019-06-24
# 2019-06-25
# 2019-06-26
# 2019-06-27
# 2019-06-28
# 2019-06-29
# 2019-06-30
# 2019-07-01
# 2019-07-02
# 2019-07-03
# 2019-07-04
# 2019-07-05
# 2019-07-06
# 2019-07-07
# 2019-07-08
# 2019-07-09
# 2019-07-10
# 2019-07-11
# 2019-07-12
# 2019-07-13
# 2019-07-14
# 2019-07-15
# 2019-07-16
# 2019-07-17
# 2019-07-18
# 2019-07-19
# 2019-07-20
# 2019-07-21
# 2019-07-22
# 2019-07-23
# 2019-07-24
# ...
